# %% [markdown]
# # 고정/정면 학습 데이터 생성

# %% [markdown]
# ## 폴더 생성

# %%
import json

# 실제 JSON 파일 경로를 여기에 입력하세요
json_file_path = 'fixed_front.json'  # 파일 경로 수정 필요

# JSON 파일 읽기
with open(json_file_path, 'r') as file:
    data = json.load(file)

# image_folder 값을 "../../Image/sample"로 변경
data['image_folder'] = "../../Image/word"

# JSON 파일 다시 저장
with open(json_file_path, 'w') as file:
    json.dump(data, file, indent=4)

print("image_folder 값이 성공적으로 변경되었습니다.")

# %%
# !mkdir -p Image/word

# %% [markdown]
# ## 압축 해제

# %%
# !apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   zip
# The following NEW packages will be installed:
#   unzip
# 0 upgraded, 1 newly installed, 0 to remove and 54 not upgraded.
# Need to get 169 kB of archives.
# After this operation, 593 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 unzip amd64 6.0-25ubuntu1.2 [169 kB]
# Fetched 169 kB in 1s (316 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package unzip.
# (Reading database ... 22856 files and directories currently installed.)
# Preparing to unpack .../unzip_6.0-25ubuntu1.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [ 20%] [###########...............................................] 8Unpacking unzip (6.0-25ubuntu1.2) ...
# ...

# %%
# !unzip -q ./koreanFontImage/01_handwriting_word_images.zip -d Image

# %%
# !unzip -q ./koreanFontImage/01_printed_word_images.zip -d Image

# %%
# !find ./Image/1_word/ -type f -print0 | xargs -0 mv -t ./Image/word/

# %% [markdown]
# ## 학습 데이터셋 생성

# %%
# %cd ./Source/Single/
# !python cut-mix-fixed-front-multiprocess.py
# %cd ./../../
# Out:
# /workspace/m-mix/S11P21S006/Model/CutMix/Source/Single
